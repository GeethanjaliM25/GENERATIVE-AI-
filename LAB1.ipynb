# %%
# !pip -q install google-genai

# %%
from google import genai
from getpass import getpass

# Enter your Gemini API key safely
api_key = getpass("Enter your Gemini API Key: ")

# Create client
client = genai.Client(api_key=api_key)
# Out:
# Enter your Gemini API Key: ··········

# %%
print("SMART ACADEMIC COMMUNICATION ASSISTANT")
print("-" * 50)

communication_type = input("Enter communication type (Notice / Email / WhatsApp Message): ")
purpose = input("Enter the purpose: ")
audience = input("Enter the target audience: ")
key_points = input("Enter the important points (comma separated): ")
tone = input("Enter the tone (Formal / Professional / Friendly / Concise): ")
length = input("Enter the length (Short / Medium / Detailed): ")
# Out:
# SMART ACADEMIC COMMUNICATION ASSISTANT
# --------------------------------------------------
# Enter communication type (Notice / Email / WhatsApp Message): Email
# Enter the purpose: Placement
# Enter the target audience: Student
# Enter the important points (comma separated): Placemet drive, IBM,12 March 2026
# Enter the tone (Formal / Professional / Friendly / Concise): Professional
# Enter the length (Short / Medium / Detailed): Detailed

# %%
prompt = f'''
You are an academic communication assistant.

Generate a {communication_type} for the following requirement.

Purpose:
{purpose}

Target Audience:
{audience}

Important Points:
{key_points}

Tone:
{tone}

Length:
{length}

Instructions:
1. The content must be clear and grammatically correct.
2. Keep it suitable for academic or official use.
3. Use proper formatting.
4. Do not add unnecessary information.
5. Make the message natural and professional.
'''

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

print("\nGENERATED OUTPUT")
print("-" * 50)
print(response.text)
# Out:
# GENERATED OUTPUT
# --------------------------------------------------
# Subject: Important Announcement: IBM Placement Drive Scheduled for March 12, 2026
#
# Dear Students,
#
# We are pleased to announce an exceptional opportunity for your career advancement through an upcoming placement drive. Our institution's Placement Cell is proud to host a recruitment event with **IBM**, a globally renowned leader in technology and innovation.
#
# This highly anticipated placement drive is scheduled to take place on **Thursday, March 12, 2026**. This presents a unique chance for eligible students to engage directly with representatives from IBM and explore potential career paths within one of the world's most prestigious technology companies.
#
# IBM is at the forefront of pioneering advancements in artificial intelligence, cloud computing, quantum computing, and enterprise solutions. A career with IBM offers unparalleled opportunities for professional growth, skill development, and the chance to contribute to impactful projects on a global scale. This drive aims to identify bright and talented individuals for various roles, including internships and full-time positions, across their diverse business units.
#
# **Key Details for the IBM Placement Drive:**
#
# *   **Company:** IBM
# *   **Date:** March 12, 2026 (Thursday)
# *   **Time & Venue:** Specific details regarding the time, venue (on-campus or virtual platform), and agenda for the day will be communicated shortly via a separate notice and on the official Placement Cell portal. Please ensure you regularly check these channels for updates.
#
# **What to Expect:**
# The drive is expected to involve various stages, which may include pre-placement talks, written tests (aptitude, technical), group discussions, and personal interviews. Detailed information regarding the selection process and specific roles offered will be shared well in advance of the drive.
#
# **Preparation is Key:**
# We strongly encourage all interested students to begin preparing immediately. This includes:
# 1.  **Resume Building:** Ensure your resume is updated, professionally formatted, and highlights your relevant skills, projects, and academic achievements.
# 2.  **Company Research:** Familiarize yourself with IBM's history, current projects, technological focus areas, values, and work culture. This will be invaluable during interviews.
# 3.  **Skill Enhancement:** Brush up on your technical skills relevant to your discipline, as well as general aptitude, logical reasoning, and communication abilities.
# 4.  **Interview Preparation:** Practice common interview questions, prepare to discuss your projects, and develop strong presentation skills.
#
# **Eligibility Criteria:**
# Specific eligibility criteria (e.g., academic percentage, stream, year of study) will be announced shortly. We advise all interested students to carefully review these criteria once published to determine their suitability for the roles offered by IBM.
#
# This is a significant opportunity to kickstart your professional journey with a leading global corporation. We urge you to take this announcement seriously and prepare diligently to make the most of this invaluable chance.
#
# For any immediate queries, please reach out to the Placement Cell.
#
# Best regards,
#
# [Your Name/Placement Coordinator Name]
# [Your Title]
# Placement Cell / Career Services Department
# [Your Institution Name]
